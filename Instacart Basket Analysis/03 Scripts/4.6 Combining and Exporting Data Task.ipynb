# %% [markdown]
# # Content List
#
# #### 01. Importing Libaries
# #### 02. Importing Dataframes
# #### 03. Merging  Orders and Products Dataframes

# %% [markdown]
# # 01. Importing Libraries

# %%
#Import libraries
import pandas as pd 
import numpy as np
import os

# %% [markdown]
# # 02. Importing Dataframes

# %%
path = r"C:\Users\maple\OneDrive\Desktop\CareerFoundry\Instacart Basket Analysis"

# %%
#In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.
df_ords_prods = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
#Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).
df_ords_prods.shape
# Out:
# (32434489, 11)

# %% [markdown]
# # 03. Merging Orders and Products Dataframes

# %%
#Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

#Importing products_checked dataframe
df_prods = pd.read_csv(os.path.join(path,'02 Data','Prepared Data', 'products_checked.csv'), index_col = False)

# %%
#Reviewing orders_products_combined columns for combination
df_ords_prods.head()
# Out:
#    order_id  user_id  number_of_orders_placed  orders_day_of_week  \
# 0   2539329        1                        1                   2
# 1   2539329        1                        1                   2
# 2   2539329        1                        1                   2
# 3   2539329        1                        1                   2
# 4   2539329        1                        1                   2
#
#    order_hour_of_day  days_since_prior_order no_prior_orders  product_id  \
# 0                  8                     NaN            True         196
# 1                  8                     NaN            True       14084
# 2                  8                     NaN            True       12427
# 3                  8                     NaN            True       26088
# 4                  8                     NaN            True       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
#Reviewing products_checked columns for combination
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#test merging dataframes
pd.merge(df_ords_prods, df_prods, on = ['product_id'],indicator = 'exists')
# Out:
#           order_id  user_id  number_of_orders_placed  orders_day_of_week  \
# 0          2539329        1                        1                   2
# 1          2398795        1                        2                   3
# 2           473747        1                        3                   3
# 3          2254736        1                        4                   4
# 4           431534        1                        5                   4
# ...            ...      ...                      ...                 ...
# 32404854   1320836   202557                       17                   2
# 32404855     31526   202557                       18                   5
# 32404856    758936   203436                        1                   2
# 32404857   2745165   203436                        2                   3
# 32404858   3093936   205420                        1                   4
#
#           order_hour_of_day  days_since_prior_order no_prior_orders  \
# ...

# %%
#Confirm the results of the merge using the merge flag.

#Merging Dataframes
df_merged = df_ords_prods.merge(df_prods, on = 'product_id', indicator = 'exists')

# %%
df_merged.head()
# Out:
#    order_id  user_id  number_of_orders_placed  orders_day_of_week  \
# 0   2539329        1                        1                   2
# 1   2398795        1                        2                   3
# 2    473747        1                        3                   3
# 3   2254736        1                        4                   4
# 4    431534        1                        5                   4
#
#    order_hour_of_day  days_since_prior_order no_prior_orders  product_id  \
# 0                  8                     NaN            True         196
# 1                  7                    15.0           False         196
# 2                 12                    21.0           False         196
# 3                  7                    29.0           False         196
# 4                 15                    28.0           False         196
#
#    add_to_cart_order  reordered _merge  Unnamed: 0 product_name  aisle_id  \
# ...

# %%
#dropping unnamed column and original merge flag
df_merged = df_merged.drop(columns=['Unnamed: 0','_merge'])

# %%
#checking new merged dataframe
df_merged.head()
# Out:
#    order_id  user_id  number_of_orders_placed  orders_day_of_week  \
# 0   2539329        1                        1                   2
# 1   2398795        1                        2                   3
# 2    473747        1                        3                   3
# 3   2254736        1                        4                   4
# 4    431534        1                        5                   4
#
#    order_hour_of_day  days_since_prior_order no_prior_orders  product_id  \
# 0                  8                     NaN            True         196
# 1                  7                    15.0           False         196
# 2                 12                    21.0           False         196
# 3                  7                    29.0           False         196
# 4                 15                    28.0           False         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# ...

# %%
df_merged['exists'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: exists, dtype: int64

# %%
df_merged.shape
# Out:
# (32404859, 15)

# %%
#Export the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size).
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
